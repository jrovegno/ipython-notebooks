# %%
from datetime import datetime
import pandas as pd
import pandas.io.data
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
pd.set_option('max_columns', 50)
# %matplotlib inline

# %%
update_from_yahoo = False

# %%
if update_from_yahoo:
    today = datetime.now()
    ipsa = pd.io.data.get_data_yahoo('^IPSA', 
                                     start=datetime(2003, 1, 10), 
                                     end=today)
    spy = pd.io.data.get_data_yahoo('SPY', 
                                     start=datetime(1993, 1, 29), 
                                     end=today)
    eem = pd.io.data.get_data_yahoo('EEM', 
                                     start=datetime(2003, 4, 15), 
                                     end=today)
    vea = pd.io.data.get_data_yahoo('VEA', 
                                     start=datetime(2007, 7, 26), 
                                     end=today)
    ipsa.to_csv('IPSA.csv')
    spy.to_csv('SPY.csv')
    eem.to_csv('EEM.csv')
    vea.to_csv('VEA.csv')

# %%
ipsa = pd.read_csv('IPSA.csv', index_col='Date', parse_dates=True, usecols=['Date','Adj Close'])
spy = pd.read_csv('SPY.csv', index_col='Date', parse_dates=True, usecols=['Date','Adj Close'])
eem = pd.read_csv('EEM.csv', index_col='Date', parse_dates=True, usecols=['Date','Adj Close'])
vea = pd.read_csv('VEA.csv', index_col='Date', parse_dates=True, usecols=['Date','Adj Close'])

# %%
afp = pd.DataFrame()
col = []

# %%
afp = afp.combineAdd(ipsa)
col.insert(0,'IPSA')
afp.columns = col

# %%
afp = afp.combineAdd(spy)
col.insert(0,'SPY')
afp.columns = col

# %%
afp = afp.combineAdd(eem)
col.insert(0,'EEM')
afp.columns = col

# %%
afp = afp.combineAdd(vea)
col.insert(0,'VEA')
afp.columns = col

# %%
afp.tail()
# Out:
#               VEA    EEM     SPY     IPSA
# Date
# 2014-02-26  41.64  39.01  184.85  3675.28
# 2014-02-27  41.81  39.75  185.82  3689.01
# 2014-02-28  41.86  39.48  186.29  3718.88
# 2014-03-03  41.01  38.78  184.98  3661.64
# 2014-03-04  41.82  39.44  187.58  3703.81
#
# [5 rows x 4 columns]

# %%
afp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5383 entries, 1993-01-29 00:00:00 to 2014-03-04 00:00:00
# Data columns (total 4 columns):
# VEA     1663 non-null float64
# EEM     2740 non-null float64
# SPY     5312 non-null float64
# IPSA    2611 non-null float64
# dtypes: float64(4)

# %%
afp.plot(subplots=True, figsize=(10, 10), sharex=True)
#plt.legend(loc='best')
# Out:
# array([<matplotlib.axes.AxesSubplot object at 0x0C4B9DB0>,
#        <matplotlib.axes.AxesSubplot object at 0x0C907CD0>,
#        <matplotlib.axes.AxesSubplot object at 0x0D0DC930>,
#        <matplotlib.axes.AxesSubplot object at 0x0D184810>], dtype=object)

# %%
afp['20140101':].plot(subplots=True, figsize=(10, 10), sharex=True)
# Out:
# array([<matplotlib.axes.AxesSubplot object at 0x0C578FF0>,
#        <matplotlib.axes.AxesSubplot object at 0x0C1CE810>,
#        <matplotlib.axes.AxesSubplot object at 0x0C803610>,
#        <matplotlib.axes.AxesSubplot object at 0x0C9185B0>], dtype=object)

# %% [raw]
# # 0,20 SPY + 0,15 IPSA + 0,17 EEM + 0,06 VEA + 0,50 dolar (interbancario del dia)
